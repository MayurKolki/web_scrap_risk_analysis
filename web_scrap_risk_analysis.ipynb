# %%
#important libraries 
import pandas as pd
from sklearn.model_selection import train_test_split,KFold
import numpy as np
from sklearn.preprocessing import LabelEncoder #(specially use to for only y )
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import f_classif

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# C:\Users\mayur\anaconda3\envs\TensorFlow\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import pandas as pd 
# List1 
lst = ('boomingbulls','codeinsight2020@gmail.com','ebiz','sarso','binomo','forex', )
df7 = pd.DataFrame(lst, columns =['email']) 
print(df7) 
df8= df7.email
# Out:
#                        email
# 0               boomingbulls
# 1  codeinsight2020@gmail.com
# 2                       ebiz
# 3                      sarso
# 4                     binomo
# 5                      forex

# %%
df8
# Out:
# 0                 boomingbulls
# 1    codeinsight2020@gmail.com
# 2                         ebiz
# 3                        sarso
# 4                       binomo
# 5                        forex
# Name: email, dtype: object

# %%
def call_goole(email,emailPerRes):
    import requests, lxml
    from bs4 import BeautifulSoup
    import re
    headers = {
        "User-Agent":
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3538.102 Safari/537.36 Edge/18.19582"
    }
    
    params = {
    'q': email,  # search query
    'hl': 'en',                # language
    'num': '100'               # number of results
    }

    html = requests.get('https://www.google.com/search', headers=headers, params=params)
    soup = BeautifulSoup(html.text, 'lxml')
    data=[]
    #out=[]
    #print(11)
    #print(soup)
    for result in soup.select('.tF2Cxc'):
     #   print(result)
        innerRes=[]
        link = result.select_one('.yuRUbf a')['href']
        displayed_link = result.select_one('.TbwUpd.NJjxre').text
        # https://stackoverflow.com/a/25703406/15164646
        domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))
        #print(email)
        data.append(domain_name)
        #print(domain_name)
        innerRes.append(email)
        innerRes.append(domain_name)
        wanted_list = ["foxrummy24","rummy","gaming","tradingview","razorpay","ebiz","sarso","trading","binomo","forex","network marketing",'gambling','spoofing','stalking','dating']
        process.extract(domain_name, wanted_list)
      #  print(23)
        #print("FuzzyWuzzy Ratio: ", fuzz.ratio(domain_name, wanted_list))
        for i in wanted_list:
            a=(fuzz.ratio(domain_name, i))
            innerRes.append(a)
            #print(a)
       # print(innerRes)    
        emailPerRes.append(innerRes) 
    return emailPerRes

# %%
emailPerRes=[]
for i in df8:
   # print(i)
    emailPerRes=call_goole(i,emailPerRes)
print(emailPerRes)
# Out:
# [['boomingbulls', 'boomingbulls.com', 23, 19, 36, 22, 8, 20, 10, 26, 36, 10, 30, 33, 42, 25, 27], ['boomingbulls', 'instagram.com', 26, 33, 32, 25, 29, 12, 44, 30, 42, 11, 20, 29, 29, 38, 32], ['boomingbulls', 'facebook.com', 27, 12, 22, 17, 20, 25, 24, 11, 33, 24, 14, 20, 20, 20, 11], ['boomingbulls', 'facebook.com', 27, 12, 22, 17, 20, 25, 24, 11, 33, 24, 14, 20, 20, 20, 11], ['boomingbulls', 'in.linkedin.com', 16, 10, 19, 23, 9, 11, 10, 27, 38, 10, 12, 26, 17, 17, 19], ['boomingbulls', 'quora.com', 21, 29, 27, 20, 35, 0, 14, 25, 27, 29, 23, 24, 24, 12, 13], ['boomingbulls', 'pages.razorpay.com', 14, 17, 17, 14, 62, 18, 26, 16, 17, 17, 23, 15, 15, 15, 17], ['boomingbulls', 'in.tradingview.com', 14, 17, 33, 76, 23, 9, 17, 56, 33, 17, 40, 31, 23, 38, 33], ['boomingbulls', 'indiaeducationdiary.in', 12, 15, 14, 24, 20, 8, 15, 14, 21, 7, 10, 13, 13, 13, 36], ['boomingbulls', 'bweducation.businessworld.in', 5, 6, 18, 26, 17, 12, 12, 17, 24, 12, 31, 17, 17, 17, 29], ['boomingbulls', 'oneindia.com', 18, 12, 22, 26, 20, 25, 12, 21, 44, 24, 28, 20, 30, 20, 22], ['boomingbulls', 'mti.edu.eg', 10, 13, 38, 29, 0, 14, 0, 35, 12, 13, 30, 33, 22, 33, 38], ['boomingbulls', 'in.pinterest.com', 15, 19, 18, 30, 8, 10, 29, 17, 36, 19, 12, 17, 17, 17, 18], ['boomingbulls', 'dumpor.com', 30, 40, 12, 10, 22, 0, 13, 12, 25, 27, 22, 11, 33, 0, 12], ['boomingbulls', 'signalhire.com', 17, 21, 20, 32, 18, 11, 42, 19, 40, 21, 13, 18, 27, 36, 20], ['boomingbulls', 'naukri.com', 20, 27, 12, 19, 22, 14, 40, 12, 38, 13, 30, 11, 11, 11, 12], ['boomingbulls', 'zaubacorp.com', 17, 22, 21, 8, 38, 12, 22, 10, 32, 22, 20, 19, 19, 10, 11], ['boomingbulls', 'mouthshut.com', 17, 22, 11, 8, 10, 0, 11, 10, 21, 11, 13, 10, 19, 10, 11], ['boomingbulls', 'highereducationdigest.com', 17, 20, 13, 33, 18, 7, 13, 31, 26, 13, 33, 12, 12, 12, 39], ['boomingbulls', 'businesstoday.in', 15, 19, 18, 22, 25, 20, 29, 17, 36, 10, 12, 25, 25, 25, 18], ['boomingbulls', 'clubhouse.com', 17, 22, 11, 8, 10, 12, 11, 0, 32, 22, 13, 10, 19, 10, 0], ['boomingbulls', 'tgstat.com', 20, 13, 38, 19, 22, 0, 40, 24, 25, 13, 15, 33, 11, 33, 25], ['boomingbulls', 'theknowledgereview.com', 19, 15, 14, 42, 13, 15, 7, 21, 21, 22, 21, 13, 13, 27, 21], ['boomingbulls', 'zoominfo.com', 27, 24, 33, 17, 20, 12, 12, 21, 33, 24, 28, 30, 40, 20, 22], ['boomingbulls', 'duforum.in', 50, 40, 38, 29, 22, 14, 13, 35, 25, 40, 37, 33, 33, 22, 38], ['boomingbulls', 'indiamart.com', 17, 22, 21, 25, 19, 12, 33, 20, 42, 11, 33, 19, 19, 19, 21], ['boomingbulls', 'udemycourses.me', 24, 30, 10, 15, 9, 11, 20, 9, 19, 10, 25, 9, 9, 9, 10], ['boomingbulls', 'speakrj.com', 19, 25, 24, 9, 21, 13, 50, 11, 24, 12, 21, 21, 32, 32, 12], ['boomingbulls', 'nocourses.com', 26, 22, 11, 17, 19, 12, 33, 10, 32, 33, 27, 10, 10, 10, 11], ['boomingbulls', 'easyleadz.com', 9, 11, 21, 17, 19, 24, 33, 20, 21, 11, 20, 19, 19, 19, 11], ['boomingbulls', 'indiatoday.in', 17, 11, 21, 25, 38, 12, 22, 20, 32, 11, 13, 19, 19, 19, 21], ['boomingbulls', 'mncjobsindia.com', 15, 19, 27, 22, 17, 20, 10, 17, 45, 10, 18, 33, 25, 25, 18], ['boomingbulls', 'coursef.com', 29, 25, 12, 18, 21, 13, 38, 11, 24, 38, 21, 11, 21, 11, 0], ['boomingbulls', 'noxinfluencer.com', 30, 18, 17, 21, 16, 10, 9, 17, 26, 18, 24, 16, 24, 16, 17], ['boomingbulls', 'outlookindia.com', 23, 19, 18, 30, 17, 10, 10, 26, 36, 10, 24, 25, 33, 42, 27], ['boomingbulls', 'chartink.com', 18, 24, 33, 26, 20, 12, 35, 32, 44, 12, 34, 30, 20, 30, 44], ['boomingbulls', 'sulekha.com', 19, 25, 24, 9, 21, 13, 38, 11, 24, 12, 21, 11, 21, 32, 12], ['boomingbulls', 'bit.ly', 12, 18, 17, 12, 14, 40, 0, 15, 33, 0, 9, 29, 14, 14, 17], ['boomingbulls', 'forbesindia.com', 32, 20, 19, 31, 26, 21, 10, 27, 48, 40, 31, 26, 26, 26, 19], ['boomingbulls', 'zeebiz.com', 20, 13, 12, 10, 22, 57, 13, 12, 50, 13, 22, 22, 11, 11, 12], ['codeinsight2020@gmail.com', 'foxrummy24.co.in', 77, 48, 27, 22, 25, 10, 10, 26, 18, 29, 30, 25, 25, 17, 18], ['codeinsight2020@gmail.com', 'foxrummy24.co.in', 77, 48, 27, 22, 25, 10, 10, 26,  ...

# %%
df8 = pd.DataFrame(emailPerRes, columns =['email', 'word', 'foxrummy24','rummy','gaming',"tradingview","razorpay","ebiz","sarso","trading","binomo","forex","network marketing",'gambling','spoofing','stalking','dating'], dtype = int)
print(df8)
# Out:
#             email               word  foxrummy24  rummy  gaming  tradingview  \
# 0    boomingbulls   boomingbulls.com          23     19      36           22
# 1    boomingbulls      instagram.com          26     33      32           25
# 2    boomingbulls       facebook.com          27     12      22           17
# 3    boomingbulls       facebook.com          27     12      22           17
# 4    boomingbulls    in.linkedin.com          16     10      19           23
# ..            ...                ...         ...    ...     ...          ...
# 426         forex   money.usnews.com          15     19      18           22
# 427         forex  orientexchange.in          15      9      26           21
# 428         forex            bbc.com          24     17      15            0
# 429         forex      bloomberg.com          26     22      21            8
# 430         forex      newsonair.com          26     22      11           25
#
#      razorpay  ebiz  sarso  trading  binomo  forex  network marketing  \
# 0           8    20     10       26      36     10                 30
# 1          29    12     44       30      42     11                 20
# 2          20    25     24       11      33     24                 14
# 3          20    25     24       11      33     24                 14
# 4           9    11     10       27      38     10                 12
# ..        ...   ...    ...      ...     ...    ...                ...
# 426        17    10     10        9      18     19                 18
# 427        24    10      9       33      17     36                 29
# 428        13    18     17        0      46     17                 17
# 429        19    12     11       20      42     22                 27
# 430        19    24     22       10      32     11                 33
#
#      gambling  spoofing  stalking  dating
# 0          33        42        25      27
# 1          29        29        38      32
# 2          20        20        20      11
# 3          20        20        20      11
# 4          26        17        17      19
# ..        ...       ...       ...     ...
# 426        17        17         8       9
# 427        24        32        24      26
# 428        13        13         0       0
# 429        29        29        19      11
# 430        10        10        10      11
#
# [431 rows x 17 columns]

# %%
print(df8[(df8['foxrummy24'] > 40) | (df8['rummy'] > 40) | (df8['gaming']>40)| (df8["tradingview"]>40)| (df8['razorpay']>40)|(df8['ebiz']>40)|(df8["sarso"]>40)|(df8["trading"]>40)|(df8["binomo"]>40)|(df8["forex"]>40)|(df8["network marketing"]>40)|(df8['gambling']>40)|(df8['spoofing']>40)|(df8['stalking']>40)|(df8['dating']>40)])
# Out:
#             email                word  foxrummy24  rummy  gaming  tradingview  \
# 0    boomingbulls    boomingbulls.com          23     19      36           22
# 1    boomingbulls       instagram.com          26     33      32           25
# 6    boomingbulls  pages.razorpay.com          14     17      17           14
# 7    boomingbulls  in.tradingview.com          14     17      33           76
# 10   boomingbulls        oneindia.com          18     12      22           26
# ..            ...                 ...         ...    ...     ...          ...
# 422         forex   wirecardforex.com          30     18       9            7
# 423         forex    giambronelaw.com          15     19      36           30
# 425         forex        livemint.com          18     24      33           17
# 428         forex             bbc.com          24     17      15            0
# 429         forex       bloomberg.com          26     22      21            8
#
#      razorpay  ebiz  sarso  trading  binomo  forex  network marketing  \
# 0           8    20     10       26      36     10                 30
# 1          29    12     44       30      42     11                 20
# 6          62    18     26       16      17     17                 23
# 7          23     9     17       56      33     17                 40
# 10         20    25     12       21      44     24                 28
# ..        ...   ...    ...      ...     ...    ...                ...
# 422        32    10     27        8      26     45                 29
# 423        25    10     29        9      36     19                 18
# 425        10    12     12       21      44     12                 28
# 428        13    18     17        0      46     17                 17
# 429        19    12     11       20      42     22                 27
#
#      gambling  spoofing  stalking  dating
# 0          33        42        25      27
# 1          29        29        38      32
# 6          15        15        15      17
# 7          31        23        38      33
# 10         20        30        20      22
# ..        ...       ...       ...     ...
# 422         8         8         8       9
# 423        42         8         8       9
# 425        30        20        30      22
# 428        13        13         0       0
# 429        29        29        19      11
#
# [165 rows x 17 columns]

# %%
df10 =df8[(df8['foxrummy24'] > 40) | (df8['rummy'] > 40) | (df8['gaming']>40)| (df8["tradingview"]>40)| (df8['razorpay']>40)|(df8['ebiz']>40)|(df8["sarso"]>40)|(df8["trading"]>40)|(df8["binomo"]>40)|(df8["forex"]>40)|(df8["network marketing"]>40)|(df8['gambling']>40)|(df8['spoofing']>40)|(df8['stalking']>40)|(df8['dating']>40)]
df10
# Out:
#             email                word  foxrummy24  rummy  gaming  tradingview  \
# 0    boomingbulls    boomingbulls.com          23     19      36           22
# 1    boomingbulls       instagram.com          26     33      32           25
# 6    boomingbulls  pages.razorpay.com          14     17      17           14
# 7    boomingbulls  in.tradingview.com          14     17      33           76
# 10   boomingbulls        oneindia.com          18     12      22           26
# ..            ...                 ...         ...    ...     ...          ...
# 422         forex   wirecardforex.com          30     18       9            7
# 423         forex    giambronelaw.com          15     19      36           30
# 425         forex        livemint.com          18     24      33           17
# 428         forex             bbc.com          24     17      15            0
# 429         forex       bloomberg.com          26     22      21            8
#
#      razorpay  ebiz  sarso  trading  binomo  forex  network marketing  \
# 0           8    20     10       26      36     10                 30
# 1          29    12     44       30      42     11                 20
# 6          62    18     26       16      17     17                 23
# 7          23     9     17       56      33     17                 40
# 10         20    25     12       21      44     24                 28
# ..        ...   ...    ...      ...     ...    ...                ...
# 422        32    10     27        8      26     45                 29
# 423        25    10     29        9      36     19                 18
# 425        10    12     12       21      44     12                 28
# 428        13    18     17        0      46     17                 17
# 429        19    12     11       20      42     22                 27
#
#      gambling  spoofing  stalking  dating
# 0          33        42        25      27
# 1          29        29        38      32
# 6          15        15        15      17
# 7          31        23        38      33
# 10         20        30        20      22
# ..        ...       ...       ...     ...
# 422         8         8         8       9
# 423        42         8         8       9
# 425        30        20        30      22
# 428        13        13         0       0
# 429        29        29        19      11
#
# [165 rows x 17 columns]

# %%
df10.email.value_counts()
# Out:
# forex                        48
# ebiz                         39
# binomo                       32
# sarso                        29
# boomingbulls                 15
# codeinsight2020@gmail.com     2
# Name: email, dtype: int64

# %%
import requests

# %%
def call_goole(email,emailPerRes):
    import requests, lxml
    from bs4 import BeautifulSoup
    import re
    headers = {
        "User-Agent":
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3538.102 Safari/537.36 Edge/18.19582"
    }
    
    params = {
    'q': email,  # search query
    'hl': 'en',                # language
    'num': '100'               # number of results
    }

    html = requests.get('https://www.google.com/search', headers=headers, params=params)
    soup = BeautifulSoup(html.content,"html.parser")
    data=[]
    #out=[]
    #print(11)
    #print(soup)
    for result in soup.select('.tF2Cxc'):
     #   print(result)
        innerRes=[]
        link = result.select_one('.yuRUbf a')['href']
        displayed_link = result.select_one('.TbwUpd.NJjxre').text
        # https://stackoverflow.com/a/25703406/15164646
        domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))
        #print(email)
        data.append(domain_name)
        #print(domain_name)
        innerRes.append(email)
        innerRes.append(domain_name)
        wanted_list = ["foxrummy24","rummy","gaming","tradingview","razorpay","ebiz","sarso","trading","binomo","forex","network marketing",'gambling','spoofing','stalking','dating']
        process.extract(domain_name, wanted_list)
      #  print(23)
        #print("FuzzyWuzzy Ratio: ", fuzz.ratio(domain_name, wanted_list))
        for i in wanted_list:
            a=(fuzz.ratio(domain_name, i))
            innerRes.append(a)
            #print(a)
       # print(innerRes)    
        emailPerRes.append(innerRes) 
    return emailPerRes

# %%
emailPerRes=[]
for i in df8:
   # print(i)
    emailPerRes=call_goole(i,emailPerRes)
print(emailPerRes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bb81994fe1e9> in <module>
#       2 for i in df8:
#       3    # print(i)
# ----> 4     emailPerRes=call_goole(i,emailPerRes)
#       5 print(emailPerRes)
#
# <ipython-input-14-ce7e15214937> in call_goole(email, emailPerRes)
#      24         innerRes=[]
#      25         link = result.select_one('.yuRUbf a')['href']
# ---> 26         displayed_link = result.select_one('.TbwUpd.NJjxre').text
#      27         # https://stackoverflow.com/a/25703406/15164646
#      28         domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
def call_goole(email,emailPerRes):
    import requests, lxml
    from bs4 import BeautifulSoup
    import re
    headers = {
        "User-Agent":
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3538.102 Safari/537.36 Edge/18.19582"
    }
    
    params = {
    'q': email,  # search query
    'hl': 'en',                # language
    'num': '100'               # number of results
    }

    html = requests.get('https://www.google.com/search', headers=headers, params=params)
    soup = BeautifulSoup(html.content,"html.parser")

# %%
html = requests.get('https://www.google.co.in/search?q=bombing+bulls&sxsrf=AOaemvLoWEcQSziyilsGv5IlzRVXHCyK7g%3A1636898733018&source=hp&ei=rBeRYa3_OoTR1sQPy4GZ6A0&iflsig=ALs-wAMAAAAAYZElvSPoWGkv0_lNATZnd-oTbbBq0_ld&oq=bombing+b&gs_lcp=...&sclient=gws-wiz')
soup = BeautifulSoup(html.content,"html.parser")
print(soup.get_text())
# Out:
# https://www.google.co.in/search?q=bombing+bulls&sxsrf=AOaemvLoWEcQSziyilsGv5IlzRVXHCyK7g%3A1636898733018&source=hp&ei=rBeRYa3_OoTR1sQPy4GZ6A0&iflsig=ALs-wAMAAAAAYZElvSPoWGkv0_lNATZnd-oTbbBq0_ld&oq=bombing+b&gs_lcp=...&sclient=gws-wiz
#
#
#
#
#
#
#
#
#
#
#
# About this page
#
# Our systems have detected unusual traffic from your computer network.  This page checks to see if it's really you sending the requests, and not a robot.  Why did this happen?
#
# This page appears when Google automatically detects requests coming from your computer network which appear to be in violation of the Terms of Service. The block will expire shortly after those requests stop.  In the meantime, solving the above CAPTCHA will let you continue to use our services.This traffic may have been sent by malicious software, a browser plug-in, or a script that sends automated requests.  If you share your network connection, ask your administrator for help — a different computer using the same IP address may be responsible.  Learn moreSometimes you may be asked to solve the CAPTCHA if you are using advanced terms that robots are known to use, or sending requests very quickly.
#
#
# IP address: 43.224.158.244Time: 2021-11-14T14:09:12ZURL: https://www.google.co.in/search?q=bombing+bulls&sxsrf=AOaemvLoWEcQSziyilsGv5IlzRVXHCyK7g%3A1636898733018&source=hp&ei=rBeRYa3_OoTR1sQPy4GZ6A0&iflsig=ALs-wAMAAAAAYZElvSPoWGkv0_lNATZnd-oTbbBq0_ld&oq=bombing+b&gs_lcp=...&sclient=gws-wiz

# %%
from bs4 import BeautifulSoup
